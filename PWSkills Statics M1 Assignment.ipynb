# %% [markdown]
# ### Assignment Solution

# %% [raw]
# 1. Explain the different types of data (qualitative and quantitative) and provide examples of each. Discuss  nominal, ordinal, interval, and ratio scales.
# Data can be classified into qualitative (categorical) and quantitative (numerical) types.
#
# Qualitative Data: Represents categories or labels.
#
# Example: Colors of cars (red, blue, black).
# Quantitative Data: Represents numerical values.
#
# Example: Heights of students in a class.
# Scales of Measurement:
#
# Nominal: Categories without order (e.g., gender, eye color).
# Ordinal: Categories with order but no fixed difference (e.g., rankings).
# Interval: Ordered data with equal differences, but no true zero (e.g., temperature in Celsius).
# Ratio: Ordered data with a true zero (e.g., weight, height).
#
# 2. What are the measures of central tendency, and when should you use each? Discuss the mean, median,  and mode with examples and situations where each is appropriate.
#
# These measures describe the center of a dataset.
#
# Mean: The average of all values. Used for symmetrical data (e.g., test scores).
# Median: The middle value when data is arranged in order. Used for skewed data (e.g., income distribution).
# Mode: The most frequently occurring value. Used for categorical data (e.g., most common shoe size)
#
# 3. Explain the concept of dispersion. How do variance and standard deviation measure the spread of data?
#
# Dispersion measures how spread out data is.
#
# Variance: The average squared difference from the mean.
# Standard Deviation: The square root of variance, showing how much data deviates from the mean.
# Higher dispersion means more variability in data.
#
# 4. What is a box plot, and what can it tell you about the distribution of data?
#
# A box plot is a graphical representation of data distribution. It shows:
#
# Median (Q2) – Middle value.
# Interquartile Range (IQR) – Middle 50% of the data.
# Whiskers – Minimum and maximum values within 1.5 × IQR.
# Outliers – Extreme values beyond whiskers.
# It helps visualize data distribution, skewness, and outliers.
#
# 5. Discuss the role of random sampling in making inferences about populations.
#
# Random sampling ensures that every individual in a population has an equal chance of selection. This helps in:
#
# Reducing bias.
# Making valid inferences about a population.
# Improving accuracy of statistical analysis.
#
# 6. Explain the concept of skewness and its types. How does skewness affect the interpretation of data?
#
# Skewness measures the asymmetry of a dataset.
#
# Positive Skew (Right Skew): Tail on the right; mean > median (e.g., salaries).
# Negative Skew (Left Skew): Tail on the left; mean < median (e.g., exam scores).
# Skewness affects statistical analysis by shifting central tendency values
#
# 7. What is the interquartile range (IQR), and how is it used to detect outliers?
#
# IQR = Q3 - Q1, where:
#
# Q1 = 25th percentile
# Q3 = 75th percentile
# Detecting Outliers:
# Any value below Q1 - 1.5 × IQR or above Q3 + 1.5 × IQR is considered an outlier.
#
# 8. Discuss the conditions under which the binomial distribution is used.
#
# A binomial distribution applies when:
#
# There are a fixed number of trials (n).
# Each trial has two outcomes (success or failure).
# The probability of success (p) remains constant.
# Trials are independent.
# Example: Tossing a coin 10 times and counting heads.
#
#
# 9. Explain the properties of the normal distribution and the empirical rule (68-95-99.7 rule).
#
# A normal distribution is symmetric and bell-shaped. The empirical rule states:
#
# 68% of data lies within 1 standard deviation (σ).
# 95% within 2σ.
# 99.7% within 3σ.
# Used in natural phenomena like height and IQ scores.
#
#
# 10. Provide a real-life example of a Poisson process and calculate the probability for a specific event.
#
# A Poisson process models rare events over a fixed interval.
#
# Example: Number of emails received per hour.
#
# If emails arrive at an average rate of 5 per hour, the probability of receiving exactly 3 emails in an hour is:
#
# P(X=3x)=(e^-5 * 5^3)/3! , this is congruent to 0.14
#
# 11. Explain what a random variable is and differentiate between discrete and continuous random variables.
#
# A random variable represents numerical outcomes of an experiment.
#
# Discrete: Takes specific values (e.g., number of heads in 10 coin tosses).
# Continuous: Takes any value in a range (e.g., height of students).
#
# 12. Provide an example dataset, calculate both covariance and correlation, and interpret the results.
#
# Given a dataset:
#
# X	Y
# 2	4
# 3	6
# 5	10
# Covariance Formula:
#
# 𝐶𝑜𝑣(𝑋,𝑌)=∑(𝑋𝑖−𝑋)(𝑌𝑖−𝑌ˉ)/𝑛−1
# Cov(X,
#
# Correlation:
#
# 𝑟=𝐶𝑜𝑣(𝑋,𝑌)/𝜎𝑋 𝜎𝑌
#
# Covariance shows the direction of the relationship.
# Correlation (range -1 to 1) shows strength and direction.
